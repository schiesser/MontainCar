# %% [markdown]
# # Mountain Car Miniproject Notebook

# %%
from agent import *
import matplotlib.pyplot as plt

# %% [markdown]
# ### Random Agent

# %%
test = RandomAgent()

# %%
test.run()
# Out:
# Episode reward after taking random actions: -200.0

# %%
positions = [ e[0] for e in test.observations]

# %%
plt.plot(positions)
